# %% [markdown]
# <a href="https://colab.research.google.com/github/fleshgordo/cocreate22/blob/main/005_examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Some xeno-canto queries:
#
# Look for specific user:
# ```
# https://xeno-canto.org/api/2/recordings?query=rec%3A%22VORNAME%20NACHNAME%22
# ```
#
# Look for links in the remarks area:
# ```
# https://xeno-canto.org/api/2/recordings?query=rmk:https
# ```

# %% [markdown]
# # Export results from xeno-canto as geo-coordinates to CSV files
#
# This will export all the results from given query into a CSV file with the column tables: "lat", "lng" and "rmk" (position latitude, longitude and comment of a recording). See the file ```sample_output/output.csv``` after running this code.

# %%
import requests
import pandas as pd

params = "cnt:switzerland loc:basel"
url="https://www.xeno-canto.org/api/2/recordings?query="+params
print(url)
r = requests.get(url, headers={"Content-Type":"json"})
resp = r.json()

df = pd.DataFrame.from_dict(resp["recordings"])
outputfile = './sample_data/output.csv'
df.dropna().to_csv(outputfile, columns = ["lat","lng","rmk"])
# Out:
# https://www.xeno-canto.org/api/2/recordings?query=cnt:switzerland loc:basel

# %% [markdown]
# # Quick xeno-canto query to pandas
#
# If you receive more than 500 results on a query, you can concatenate some of the requests in a big pandas dataframe by manually changing the page number.

# %%
import requests
import pandas as pd

# making the request
params = "cnt:germany&page=5" # change page=1, page=2, page=3 etc. if there are more than 500results
url="https://www.xeno-canto.org/api/2/recordings?query="+params
r = requests.get(url, headers={"Content-Type":"json"})
resp = r.json()
#print(resp)

# creating a new dataframe in case there's none, otherwise concatening existing one
if df is None:
  print("first runtime ... creating dataframe")
  df = pd.DataFrame.from_dict(resp["recordings"])
else:
  df = pd.concat([df, pd.DataFrame.from_dict(resp["recordings"])])
  print("adding " + str(len(resp["recordings"])) + " entries to existing dataframe")
  print("currently " + str(len(df.index)) + " entries in dataframe")
# Out:
# adding 500 entries to existing dataframe
# currently 4000 entries in dataframe

# %%
df
# Out:
#          id        gen         sp ssp                 en  \
# 0    127145       Rhea  americana           Greater Rhea
# 1    127143       Rhea  americana           Greater Rhea
# 2    133402  Tetrastes    bonasia           Hazel Grouse
# 3    437461  Tetrastes    bonasia           Hazel Grouse
# 4    437459  Tetrastes    bonasia           Hazel Grouse
# ..      ...        ...        ...  ..                ...
# 495  479633   Scolopax  rusticola      Eurasian Woodcock
# 496  479631   Scolopax  rusticola      Eurasian Woodcock
# 497  478431   Scolopax  rusticola      Eurasian Woodcock
# 498  288943   Scolopax  rusticola      Eurasian Woodcock
# 499  665617   Scolopax  rusticola      Eurasian Woodcock
#
#                       rec      cnt  \
# 0           Lars Lachmann  Germany
# 1           Lars Lachmann  Germany
# 2    Matthias Feuersenger  Germany
# 3          Julia Wittmann  Germany
# 4          Julia Wittmann  Germany
# ..                    ...      ...
# 495       Frank Holzapfel  Germany
# 496       Frank Holzapfel  Germany
# 497         Stephan Risch  Germany
# 498           Nils Agster  Germany
# 499       Frank Holzapfel  Germany
#
#                                                    loc      lat      lng  ...  \
# 0                              east of Ratzeburger See  53.7688  10.7742  ...
# 1                              east of Ratzeburger See  53.7688  10.7742  ...
# 2    Near Stellwand, Oberammergau, Upper Bavaria, B...  47.5397  10.9783  ...
# 3    Finsterauer Filz, Freyung-Grafenau (near  Maut...  48.9492  13.5775  ...
# 4    Finsterauer Filz, Freyung-Grafenau (near  Maut...  48.9492  13.5775  ...
# ..                                                 ...      ...      ...  ...
# 495  Naturpark Stromberg-Heuchelberg, Baden-Württem...  48.9785   8.9145  ...
# 496  Naturpark Stromberg-Heuchelberg, Baden-Württem...  48.9785   8.9145  ...
# 497          Solingen, Düsseldorf, Nordrhein-Westfalen  51.1572   6.9713  ...
# 498  Tübingen (near  Rottenburg am Neckar), Tübinge...  48.4213   8.9489  ...
# 499  Naturpark Stromberg-Heuchelberg, Baden-Württem...  49.0063   8.9053  ...
#
#                                               lic  q length   time  \
# 0    //creativecommons.org/licenses/by-nc-sa/3.0/  B   0:03  14:29
# 1    //creativecommons.org/licenses/by-nc-sa/3.0/  D   0:02  14:26
# 2    //creativecommons.org/licenses/by-nc-sa/3.0/  A   0:25  08:40
# 3    //creativecommons.org/licenses/by-nc-sa/4.0/  B   0:20  06:35
# 4    //creativecommons.org/licenses/by-nc-sa/4.0/  B   0:19  06:35
# ..                                            ... ..    ...    ...
# 495  //creativecommons.org/licenses/by-nc-nd/4.0/  C   0:40  21:10
# 496  //creativecommons.org/licenses/by-nc-nd/4.0/  C   0:36  20:52
# 497  //creativecommons.org/licenses/by-nc-sa/4.0/  C   0:02  21:52
# 498  //creativecommons.org/licenses/by-nc-sa/4.0/  C   0:12  22:00
# 499  //creativecommons.org/licenses/by-nc-nd/4.0/  D   0:20  21:37
#
#            date    uploaded  \
# 0    2013-02-16  2013-03-24
# 1    2013-02-16  2013-03-24
# 2    2013-05-03  2013-05-12
# 3    2018-09-30  2018-10-06
# 4    2018-09-30  2018-10-06
# ..          ...         ...
# 495  2019-05-01  2019-06-08
# 496  2019-05-01  2019-06-08
# 497  2016-06-18  2019-06-02
# 498  2015-06-03  2015-11-07
# 499  2021-06-02  2021-07-30
#
#                                                   also  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3    [Turdus philomelos, Prunella modularis, Fringi...
# 4                   [Turdus merula, Turdus philomelos]
# ..                                                 ...
# 495                                                 []
# 496                                                 []
# 497                                                 []
# 498                                                 []
# 499                                                 []
#
#                                                    rmk bird-seen playback-used
# 0    snorting sound given during aggressin between ...   unknown       unknown
# 1    booming song of a male bird. There is now a fe...       yes            no
# 2    Bird singing from the ground in moist young mi...       yes            no
# 3                                                            yes            no
# 4                                                            yes            no
# ..                                                 ...       ...           ...
# 495  Cut 3 of 17:  Woodcock's high pitched "pist" e...       yes            no
# 496  Cut 1 of 17: The Woodcock songster shows up 12...       yes            no
# 497  Three Calls automatically recorded (Pettersson...        no            no
# 498                                                          yes            no
# 499  Roding area of Eurasian Woodcock *Scolopax rus...       yes            no
#
# [4000 rows x 26 columns]
# Warning: Total number of columns (26) exceeds max_columns (20) limiting to first (20) columns.

# %% [markdown]
# # Extract all links from results
#
# Looks for links with the search term ```https``` and makes a query (```https://xeno-canto.org/api/2/recordings?query=rmk%3A%22https%22```). Later on, extracting the URLs from the remark section and store them in a list.

# %%
import requests
import pandas as pd
import re

#params = "rmk:https cnt:Switzerland loc:Basel"
params = "rmk:https cnt:Brazil"
#params = "rmk:youtube cnt:Germany" 

url="https://www.xeno-canto.org/api/2/recordings?query="+params

r = requests.get(url, headers={"Content-Type":"json"})
resp = r.json()

print("there are " + str(len(resp["recordings"])) + " recordings with links in the remark section")
comments = resp["recordings"]
# Out:
# there are 156 recordings with links in the remark section

# %% [markdown]
# For extracting all hyperlinks in the comments we need a regular expression and to extract within each remark the link that starts with https:// ...

# %%
urls = []
for comment in comments:
    regularex = r'(https:[\'"]?[^\'"\) >]+)'
    url = re.findall(regularex, comment["rmk"])
    urls.extend(url)
    print(url)
print("could extract " + str(len(urls)) + " hyperlinks")

# %% [markdown]
# ## Pivottable
#
# For quick exploration of a dataframe [pivottablejs](https://pivottable.js.org/) is quite useful. Install it via pip:

# %%
# install 
# !pip install pivottablejs
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pivottablejs
#   Downloading pivottablejs-0.9.0-py2.py3-none-any.whl (4.7 kB)
# Installing collected packages: pivottablejs
# Successfully installed pivottablejs-0.9.0

# %%
# create a df from download
import requests
import pandas as pd
all_animals = requests.get("https://github.com/fleshgordo/cocreate22/raw/main/sample_data/20220917-181514-api-all-animals.json")
all_animals = all_animals.json()
df = pd.json_normalize(all_animals["data"])
df
# Out:
#                                         id    type  \
# 0     7e9f780e-0acb-4e9c-a813-1c30b1cd0e68  animal
# 1     4ff7d460-f936-49a4-a00d-56c208e44641  animal
# 2     24cc5ea8-dcc4-419d-9f90-f5a668c14895  animal
# 3     48c7a06e-f5f3-4133-b04e-c7980d3e35d1  animal
# 4     a97c7725-cd9a-4840-a942-5f52d4a12d4a  animal
# ...                                    ...     ...
# 5065  c2aa97ab-f4f7-4f4e-bc21-689f4f6eea9e  animal
# 5066  07a57a88-2f46-4aaf-a4cc-06d90d4f2188  animal
# 5067  45c8f98d-a209-46d3-b330-b9aadd9eb02c  animal
# 5068  96a0014e-c310-4b32-9813-78690dbf5154  animal
# 5069  c1cff0e4-e184-43d3-bc55-4cf97ffd0c1b  animal
#
#                              attributes.id  attributes.alive  \
# 0     7e9f780e-0acb-4e9c-a813-1c30b1cd0e68              True
# 1     4ff7d460-f936-49a4-a00d-56c208e44641              True
# 2     24cc5ea8-dcc4-419d-9f90-f5a668c14895              True
# 3     48c7a06e-f5f3-4133-b04e-c7980d3e35d1              True
# 4     a97c7725-cd9a-4840-a942-5f52d4a12d4a              True
# ...                                    ...               ...
# 5065  c2aa97ab-f4f7-4f4e-bc21-689f4f6eea9e              True
# 5066  07a57a88-2f46-4aaf-a4cc-06d90d4f2188              True
# 5067  45c8f98d-a209-46d3-b330-b9aadd9eb02c              True
# 5068  96a0014e-c310-4b32-9813-78690dbf5154              True
# 5069  c1cff0e4-e184-43d3-bc55-4cf97ffd0c1b              True
#
#      attributes.ring_id  attributes.distance_24h_m attributes.name  \
# 0                                              NaN            02a9
# 1            0679-01594                        NaN         Charlie
# 2            0679-01596                        NaN           Pilot
# 3            0709-01883                        NaN        Wanderer
# 4            0709-02458                        NaN            Taku
# ...                 ...                        ...             ...
# 5065                                          41.0        ZOO w-wa
# 5066                164                     6585.0           Zoppo
# 5067                                           NaN         Unnamed
# 5068                                           NaN         Unnamed
# 5069                                           NaN    TowerJunct_F
#
#       attributes.is_highlighted  \
# 0                         False
# 1                         False
# 2                         False
# 3                         False
# 4                         False
# ...                         ...
# 5065                      False
# 5066                      False
# 5067                      False
# 5068                      False
# 5069                      False
#
#                                  attributes.content_url attributes.image_url  \
# 0     https://animaltracker.app/api/v1/animals/7e9f7...                 None
# 1     https://animaltracker.app/api/v1/animals/4ff7d...                 None
# 2     https://animaltracker.app/api/v1/animals/24cc5...                 None
# 3     https://animaltracker.app/api/v1/animals/48c7a...                 None
# 4     https://animaltracker.app/api/v1/animals/a97c7...                 None
# ...                                                 ...                  ...
# 5065  https://animaltracker.app/api/v1/animals/c2aa9...                 None
# 5066  https://animaltracker.app/api/v1/animals/07a57...                 None
# 5067  https://animaltracker.app/api/v1/animals/45c8f...                 None
# 5068  https://animaltracker.app/api/v1/animals/96a00...                 None
# 5069  https://animaltracker.app/api/v1/animals/c1cff...                 None
#
#       attributes.last_location.latitude  attributes.last_location.longitude  \
# 0                             24.431216                           32.757590
# 1                             46.555000                         -112.861700
# 2                             47.226100                         -113.310800
# 3                             46.206170                         -113.894830
# 4                             58.567170                         -131.969170
# ...                                 ...                                 ...
# 5065                          40.019037                           30.030342
# 5066                          47.790104                            9.287352
# 5067                          35.063362                          -77.088932
# 5068                          34.844276                          -76.419373
# 5069                          44.909236                         -110.420282
#
#      attributes.last_location.timestamp          relationships.specie.data.id  \
# 0         2022-08-27T16:01:26.000+02:00  b3eeb878-4aa2-4a2e-aaa7-c4929a6d9266
# 1         2022-04-11T01:00:11.000+02:00  82c04a5e-162d-4054-9ea1-dac19545d5a0
# 2         2022-09-08T01:00:33.000+02:00  82c04a5e-162d-4054-9ea1-dac19545d5a0
# 3         2022-08-11T23:00:00.000+02:00  82c04a5e-162d-4054-9ea1-dac19545d5a0
# 4         2022-09-16T03:00:00.000+02:00  82c04a5e-162d-4054-9ea1-dac19545d5a0
# ...                                 ...                                   ...
# 5065      2022-09-16T20:58:16.000+02:00  b3eeb878-4aa2-4a2e-aaa7-c4929a6d9266
# 5066      2022-09-17T16:50:15.000+02:00  66520f65-b48d-4ef7-b65b-7efec70f061d
# 5067      2015-05-15T21:01:11.000+02:00  ce105134-d90e-47dd-a75f-4d2c28cd3e64
# 5068      2022-05-15T14:10:03.000+02:00  51515a23-0dce-4c34-b6e0-1179b36575a5
# 5069      2021-12-11T19:00:11.000+01:00  840ca53f-c3b0-4458-91a6-728a0e208479
#
#      relationships.specie.data.type
# 0                            specie
# 1                            specie
# 2                            specie
# 3                            specie
# 4                            specie
# ...                             ...
# 5065                         specie
# 5066                         specie
# 5067                         specie
# 5068                         specie
# 5069                         specie
#
# [5070 rows x 15 columns]

# %%
# create the pivottable
from pivottablejs import pivot_ui # import pivottable
pivot_ui(df,outfile_path="sample_data/pivottablejs.html") # will save the html to folder

# %% [markdown]
# This will create pivottablejs.html in the sample_data folder. Remember without pivottable your code might look like this [link text](https://miro.medium.com/max/1272/1*kuIcMlTi8VzVCZXm47I8hQ.png)

# %% [markdown]
# # Pivottable for xeno-canto

# %%
from IPython.core.display import HTML
import pandas as pd
import requests
from pivottablejs import pivot_ui # import pivottable

# fetch data from server
params = "cnt:switzerland loc:basel"
url="https://www.xeno-canto.org/api/2/recordings?query="+params
r = requests.get(url, headers={"Content-Type":"json"})
resp = r.json()

# tranform json response into panda's dataframe 
df = pd.DataFrame(resp["recordings"])

# create interactive pivottable
pivot_ui(df,outfile_path="sample_data/pivot_canto.html") # will save the html to folder
HTML("sample_data/pivot_canto.html")
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>PivotTable.js</title>
#
#         <!-- external libs from cdnjs -->
#         <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/c3/0.4.11/c3.min.css">
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js"></script>
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/c3/0.4.11/c3.min.js"></script>
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jquery/1.11.2/jquery.min.js"></script>
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.11.4/jquery-ui.min.js"></script>
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jquery-csv/0.71/jquery.csv-0.71.min.js"></script>
#
#
#         <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/pivottable/2.19.0/pivot.min.css">
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/pivottable/2.19.0/pivot.min.js"></script>
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/pivottable/2.19.0/d3_renderers.min.js"></script>
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/pivottable/2.19.0/c3_renderers.min.js"></script>
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/pivottable/2.19.0/export_renderers.min.js"></script>
#
#         <style>
#             body {font-family: Verdana;}
#             .node {
#               border: solid 1px white;
#               font: 10px sans-serif;
#               line-height: 12px;
#               overflow: hidden;
#               position: absolute;
#               text-indent: 2px;
#             }
#             .c3-line, .c3-focused {stroke-width: 3px !important;}
#             .c3-bar {stroke: white !important; stroke-width: 1;}
#             .c3 text { font-size: 12px; color: grey;}
#             .tick line {stroke: white;}
#             .c3-axis path {stroke: grey;}
#             .c3-circle { opacity: 1 !important; }
#             .c3-xgrid-focus {visibility: hidden !important;}
#         </style>
#     </head>
#     <body>
#         <script type="text/javascript">
#             $(function(){
#                 if(window.location != window.parent.location)
#                     $("<a>", {target:"_blank", href:""})
#                         .text("[pop out]").prependTo($("body"));
#
#                 $("#output").pivotUI(
#                     $.csv.toArrays($("#output").text()),
#                     $.extend({
#                         renderers: $.extend(
#                             $.pivotUtilities.renderers,
#                             $.pivotUtilities.c3_renderers,
#                             $.pivotUtilities.d3_renderers,
#                             $.pivotUtilities.export_renderers
#                             ),
#                         hiddenAttributes: [""]
#                     }, {})
#                 ).show();
#              });
#         </script>
#         <div id="output" style="display: none;">,id,gen,sp,ssp,en,rec,cnt,loc,lat,lng,alt,type,url,file,file-name,sono,lic,q,length,time,date,uploaded,also,rmk,bird-seen,playback-used
# 0,383063,Tachymarptis,melba,,Alpine Swift,Peter Ertl,Switzerland,"Basel, Basel-Stadt, Basel-Stadt",47.5734,7.5767,260,call,//xeno-canto.org/383063,https://xeno-canto.org/383063/download,XC383063-alpensegler.mp3,"{'small': '//xeno-canto.org/sounds/uploaded/ZGGFYJIGKA/ffts/XC383063-small.png', 'med': '//xeno-canto.org/sounds/uploaded/ZGGFYJIGKA/ffts/XC383063-med.png', 'large': '//xeno-canto.org/sounds/uploaded/ZGGFYJIGKA/ffts/XC383063-large.png', 'full': '//xeno-canto.org/sounds/uploaded/ZGGFYJIGKA/ffts/XC383063-full.png'}",//creativecommons.org/licenses/by-nc-sa/4.0/,A,0:13,09:30,2017-08-14,2017-08-14,[''],call from a nest,unknown,unknown
# 1,530514,Gallinula,chloropus,,Common Moorhen,Samuel Büttler,Switzerland,"Basel, Basel-Stadt, Basel-Stadt",47.5401,7.5965,280,"call, nocturnal flight call",//xeno-canto.org/530514,https://xeno-canto.org/530514/download,XC530514-Teichhuhn1 27 2 20 (online-audio-converter.com).mp3,"{'small': '//xeno-canto.org/sounds/uploaded/XOIKQWVJSA/ffts/XC530514-small.png', 'med': '//xeno-canto.org/sounds/uploaded/XOIKQWVJSA/ffts/XC530514-med.png', 'large': '//xeno-canto.org/sounds/uploaded/XOIKQWVJSA/ffts/XC530514-large.png', 'full': '//xeno-canto.org/sounds/uploaded/XOIKQWVJSA/ffts/XC530514-full.png'}",//creativecommons.org/licenses/by-nc-sa/4.0/,C,0:07,05:00,2020-02-27,2020-02-27,[''],,no,no
# 2,719785,Milvus,migrans,,Black Kite,Nicolas Martinez,Switzerland,"Brislach, Laufen District, Basel-Landschaft",47.4312,7.5357,420,song,//xeno-canto.org/719785,https://xeno-canto.org/719785/download,XC719785-milmig_20220427_breitenbach_ZOOM0309_Tr1.mp3,"{'small': '//xeno-canto.org/sounds/uploaded/CVLRXNQXVL/ffts/XC719785-small.png', 'med': '//xeno-canto.org/sounds/uploaded/CVLRXNQXVL/ffts/XC719785-med.png', 'large': '//xeno-canto.org/sounds/uploaded/CVLRXNQXVL/ffts/XC719785-large.png', 'full': '//xeno-canto.org/sounds/uploaded/CVLRXNQXVL/ffts/XC719785-full.png'}",//creativecommons.org/licenses/by-nc-sa/4.0/,B,1:16,08:15,2022-04-27,2022-04-27,[''],,yes,no
# 3,530385,Tyto,alba,,Western Barn Owl,Samuel Büttler,Switzerland,"Basel, Basel-Stadt, Basel-Stadt",47.5399,7.5964,280,"call, nocturnal flight call",//xeno-canto.org/530385,https://xeno-canto.org/530385/download,XC530385-Schleiereule250220 (online-audio-converter.com).mp3,"{'small': '//xeno-canto.org/sounds/uploaded/XOIKQWVJSA/ffts/XC530385-small.png', 'med': '//xeno-canto.org/sounds/uploaded/XOIKQWVJSA/ffts/XC530385-med.png', 'large': '//xeno-canto.org/sounds/uploaded/XOIKQWVJSA/ffts/XC530385-large.png', 'full': '//xeno-canto.org/sounds/uploaded/XOIKQWVJSA/ffts/XC530385-full.png'}",//creativecommons.org/licenses/by-nc-sa/4.0/,B,0:07,03:50,2020-02-25,2020-02-26,[''],,no,no
# 4,534666,Bubo,bubo,,Eurasian Eagle-Owl,Jaro Schacht,Switzerland,Basel-Land,,,800,"aberrant, adult, male, song",//xeno-canto.org/534666,https://xeno-canto.org/534666/download,XC534666-Uhu J.01.MP3,"{'small': '//xeno-canto.org/sounds/uploaded/JGJWSKLOEW/ffts/XC534666-small.png', 'med': '//xeno-canto.org/sounds/uploaded/JGJWSKLOEW/ffts/XC534666-med.png', 'large': '//xeno-canto.org/sounds/uploaded/JGJWSKLOEW/ffts/XC534666-large.png', 'full': '//xeno-canto.org/sounds/uploaded/JGJWSKLOEW/ffts/XC534666-full.png'}",//creativecommons.org/licenses/by-nc-sa/4.0/,B,0:20,20:30,2020-03-14,2020-03-15,[''],,yes,unknown
# 5,723332,Strix,aluco,,Tawny Owl,Nicolas Martinez,Switzerland,"Bottmingen, Arlesheim, Basel-Landschaft",47.5243,7.5634,340,"call, song",//xeno-canto.org/723332,https://xeno-canto.org/723332/download,XC723332-stralu_20220510_oberwil_rauschv_ZOOM0324_Tr1.mp3,"{'small': '//xeno-canto.org/sounds/uploaded/CVLRXNQXVL/ffts/XC723332-small.png', 'med': '//xeno-canto.org/sounds/uploaded/CVLRXNQXVL/ffts/XC723332-med.png', 'large': '//xeno-canto.org/sounds/uploaded/CVLRXNQXVL/ffts/XC723332-large.png', 'full': '//xeno-canto.org/sounds/uploaded/CVLRXNQXVL/ffts/XC723332-full.png'}",//creativecommons.org/licenses/by-nc-sa/4.0/,A,0:51,21:30,2022-05-10,2022-05-10,[''],,no,no
# 6,723331,Strix,aluco,,Tawny Owl,Nicolas Martinez,Switzerland,"Bottmingen, Arlesheim, Basel-Landschaft",47.5243,7.5634,340,song,//xeno-canto.org/723331,https://xeno-canto.org/723331/download,XC723331-stralu_20220510_oberwil_rauschver_ZOOM0323_Tr1.mp3,"{'small': '//xeno-canto.org/sounds/uploaded/CVLRXNQXVL/ffts/XC723331-small.png', 'med': '//xeno-canto.org/sounds/uploaded/CVLRXNQXVL/ffts/XC723331-med.png', 'large': '//xeno-canto.org/sounds/uploaded/CVLRXNQXVL/ffts/XC723331-large.png', 'full': '//xeno-canto.org/sounds/uploaded/CVLRXNQXVL/ffts/XC723331-full.png'}",//creativecommons.org/licenses/by-nc-sa/4.0/,A,2:48,21:30,2022-05-10,2022-05-10,['Erithacus rubecula'],,no,no
# 7,724903,Jynx,torquilla,,Eurasian Wryneck,Nicolas Martinez,Switzerland,"Riehen, Basel-Stadt, Basel-Stadt",47.5966,7.6467,32
